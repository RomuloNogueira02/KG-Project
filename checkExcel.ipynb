# %%
import pickle
import pandas as pd
import rdflib

# %%
df = pd.read_excel(r"/Users/pedroserrano/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Work_obsidian/Uni/Mestrado/2semester/Redes/Projeto/KG-Project/alignment_result.xlsx")
print(df)
# Out:
#                                    ontology 1  \
# 0                                         lip
# 1                  seminal vesicle epithelium
# 2                      nasopharynx epithelium
# 3                       oropharynx epithelium
# 4                           pancreatic acinus
# ...                                       ...
# 1367                                   cavity
# 1368                              c2 vertebra
# 1369  inner segment of the photoreceptor cell
# 1370     postganglionic parasympathetic fiber
# 1371                        splenic arteriole
#
#                                     ontology 2     score
# 0                                          lip  1.000000
# 1                   seminal vesicle epithelium  1.000000
# 2                       nasopharynx epithelium  1.000000
# 3                        oropharynx epithelium  1.000000
# 4                            pancreatic acinus  1.000000
# ...                                        ...       ...
# ...

# %%
maybe_align = {}
ontology1_list = df['ontology 1'].tolist()
ontology2_list = df['ontology 2'].tolist()
score = df['score'].tolist()

for i in range(len(score)):
    maybe_align[ontology1_list[i], ontology2_list[i]] = score[i]

print(maybe_align)

#if its stupid and it works, it aint stupid
#so queria passar o excel para o dictionary do costume
# Out:
# {('lip', 'lip'): 1.0, ('seminal vesicle epithelium', 'seminal vesicle epithelium'): 1.0, ('nasopharynx epithelium', 'nasopharynx epithelium'): 1.0, ('oropharynx epithelium', 'oropharynx epithelium'): 1.0, ('pancreatic acinus', 'pancreatic acinus'): 1.0, ('penis erectile tissue', 'penis erectile tissue'): 1.0, ('prepuce epithelium', 'prepuce epithelium'): 1.0, ('renal tubule basement membrane', 'renal tubule basement membrane'): 1.0, ('renal tubule epithelium', 'renal tubule epithelium'): 1.0, ('right lung alveolar duct', 'right lung alveolar duct'): 1.0, ('right lung alveolus', 'right lung alveolus'): 1.0, ('right lung bronchiole', 'right lung bronchiole'): 1.0, ('right lung respiratory bronchiole', 'right lung respiratory bronchiole'): 1.0, ('right lung terminal bronchiole', 'right lung terminal bronchiole'): 1.0, ('tongue epithelium', 'tongue epithelium'): 1.0, ('nasal cavity epithelium', 'nasal cavity epithelium'): 1.0, ('trachea basement membrane', 'trachea basement membrane'): 1
# ...
