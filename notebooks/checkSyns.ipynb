# %%
from functions import *

# %%
ontology = loadOntology("ontologies/anatomy/mouse.owl")
for c in ontology.classes():
    # print(c.namespace)
    try: 
        for syn in c.hasRelatedSynonym:
            print(c.label, syn.label)
    except:
        pass
# Out:
# ['adult mouse'] ['TS28']
# ['trunk'] ['body']
# ['limb'] ['extremity']
# ['cardiovascular system'] ['circulatory system']
# ['hemolymphoid system'] ['haemolymphoid system']
# ['abdomen/pelvis/perineum'] ['lower body']
# ['thorax'] ['upper body']
# ['chest'] ['thoracic body wall']
# ['lower arm'] ['forearm']
# ['autopod'] ['paw']
# ['hematopoietic system'] ['hemopoietic system']
# ['hematopoietic system'] ['haematopoietic system']
# ['blood vessel'] ['vasculature']
# ['myocardium'] ['cardiac muscle']
# ['atrial septum'] ['interatrial septum']
# ['ventricular septum'] ['interventricular septum']
# ['mitral valve'] ['bicuspid valve']
# ['atrioventricular node'] ['AV node']
# ['sinoatrial node'] ['SA node']
# ['adrenal gland'] ['suprarenal gland']
# ['pancreas body'] ['pancreas corpus']
# ['pancreatic islet'] ['islet of langerhans']
# ['cerebral hemisphere'] ['cerebrum']
# ['telencephalon'] ['telencephalic vesicle']
# ['telencephalon'] ['cerebrum']
# ...

# %%
for a in ontology.annotation_properties():
    print(a)
# Out:
# rdf-schema.label
# oboInOwl.hasRelatedSynonym
# oboInOwl.hasDefaultNamespace
# oboInOwl.savedBy
# oboInOwl.hasDate
# oboInOwl.hasDbXref
# oboInOwl.hasAlternativeId
